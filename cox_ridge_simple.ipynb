# %% [markdown]
# # Cox Regression Penalized

# %% [markdown]
# ### Imports

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sksurv.ensemble import RandomSurvivalForest
from sksurv.linear_model import CoxnetSurvivalAnalysis
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import concordance_index_censored , concordance_index_ipcw
from sklearn.impute import SimpleImputer
from sksurv.util import Surv

# Clinical Data
df = pd.read_csv("./data/X_train/clinical_train.csv")
df_eval = pd.read_csv("./data/X_test/clinical_test.csv")

# Molecular Data
maf_df = pd.read_csv("./data/X_train/molecular_train.csv")
maf_eval = pd.read_csv("./data/X_test/molecular_test.csv")

target_df = pd.read_csv("./data/target_train.csv")

# TODO : Uncomment for test data ??
"""
target_df_test = pd.read_csv("./data/target_test.csv")
"""
# Preview the data
df.head()
# Out:
#         ID CENTER  BM_BLAST    WBC  ANC  MONOCYTES    HB    PLT  \
# 0  P132697    MSK      14.0    2.8  0.2        0.7   7.6  119.0
# 1  P132698    MSK       1.0    7.4  2.4        0.1  11.6   42.0
# 2  P116889    MSK      15.0    3.7  2.1        0.1  14.2   81.0
# 3  P132699    MSK       1.0    3.9  1.9        0.1   8.9   77.0
# 4  P132700    MSK       6.0  128.0  9.7        0.9  11.1  195.0
#
#                           CYTOGENETICS
# 0      46,xy,del(20)(q12)[2]/46,xy[18]
# 1                                46,xx
# 2   46,xy,t(3;3)(q25;q27)[8]/46,xy[12]
# 3    46,xy,del(3)(q26q27)[15]/46,xy[5]
# 4  46,xx,t(3;9)(p13;q22)[10]/46,xx[10]

# %% [markdown]
# ### Cleaning

# %%
# Drop rows where 'OS_YEARS' is NaN if conversion caused any issues
target_df.dropna(subset=['OS_YEARS', 'OS_STATUS'], inplace=True)

# Check the data types to ensure 'OS_STATUS' is boolean and 'OS_YEARS' is numeric
print(target_df[['OS_STATUS', 'OS_YEARS']].dtypes)

# Contarget_dfvert 'OS_YEARS' to numeric if it isn’t already
target_df['OS_YEARS'] = pd.to_numeric(target_df['OS_YEARS'], errors='coerce')

# Ensure 'OS_STATUS' is boolean
target_df['OS_STATUS'] = target_df['OS_STATUS'].astype(bool)
# Out:
# OS_STATUS    float64
# OS_YEARS     float64
# dtype: object

# %% [markdown]
# 1. Extracting number of somatic mutations

# %%
# Step: Extract the number of somatic mutations per patient
# Group by 'ID' and count the number of mutations (rows) per patient
tmp = maf_df.groupby('ID').size().reset_index(name='Nmut')

# Merge with the training dataset and replace missing values in 'Nmut' with 0
df_2 = df.merge(tmp, on='ID', how='left').fillna({'Nmut': 0})

# %% [markdown]
# 2. One hot encoding 'GENE'

# %%
# One-hot encode the 'GENE' column
one_hot_encoded_genes = pd.get_dummies(maf_df['GENE'], prefix='GENE')

# Add the one-hot encoded columns to the original DataFrame
maf_df_one_hot = pd.concat([maf_df[['ID']], one_hot_encoded_genes], axis=1)

# Group by 'ID' and aggregate using max to ensure one entry per ID
maf_df_one_hot_grouped = maf_df_one_hot.groupby('ID').max().reset_index()

maf_df_one_hot_grouped.head()
# Out:
#         ID  GENE_ABL1  GENE_ARID1A  GENE_ARID2  GENE_ASXL1  GENE_ASXL2  \
# 0  P100000      False        False       False       False       False
# 1  P100001      False        False       False       False       False
# 2  P100002      False        False       False       False       False
# 3  P100004      False        False       False       False       False
# 4  P100006      False        False       False       False       False
#
#    GENE_ATRX  GENE_BAP1  GENE_BCL10  GENE_BCOR  ...  GENE_TET2  GENE_TP53  \
# 0      False      False       False      False  ...       True      False
# 1      False      False       False      False  ...      False      False
# 2      False      False       False      False  ...      False       True
# 3      False      False       False      False  ...      False      False
# 4      False      False       False      False  ...       True      False
#
#    GENE_U2AF1  GENE_U2AF2  GENE_WHSC1  GENE_WT1  GENE_ZBTB33  GENE_ZMYM3  \
# 0       False       False       False     False        False       False
# 1       False       False       False     False        False       False
# 2       False       False       False     False        False       False
# 3       False       False       False     False        False       False
# 4       False       False       False     False        False       False
#
#    GENE_ZNF318  GENE_ZRSR2
# 0        False       False
# 1        False       False
# 2        False       False
# 3        False       False
# 4        False       False
#
# [5 rows x 125 columns]

# %% [markdown]
# 3. Selecting features and getting rid of rows with NaN values in training set

# %%
# Select features and target columns
features = ['BM_BLAST', 'HB', 'PLT', 'Nmut']
one_hot_features = list(maf_df_one_hot_grouped.columns[1:])
target = ['OS_YEARS', 'OS_STATUS']

# Merge on ID to ensure same row order
merged = df_2[['ID'] + features].merge(target_df[['ID'] + target], on='ID', how='left')
merged = merged.merge(maf_df_one_hot_grouped, on='ID', how='left')  # Merge one-hot encoded genes

# Remove rows with missing feature values
merged = merged.dropna()

# Build feature matrix and survival target
X = merged[features+one_hot_features]
y = Surv.from_dataframe('OS_STATUS', 'OS_YEARS', merged[target])

# %% [markdown]
# 4. Spliting dataset

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.head()
# Out:
#       BM_BLAST    HB    PLT  Nmut GENE_ABL1 GENE_ARID1A GENE_ARID2 GENE_ASXL1  \
# 787       10.0   8.4  300.0   6.0     False       False      False       True
# 1270       4.0   7.5  182.0   2.0     False       False      False      False
# 1594       1.0  11.2  212.0   3.0     False       False      False      False
# 2073       0.0   7.0  410.0   2.0     False       False      False      False
# 2052       3.0  12.0  195.0   4.0     False       False      False      False
#
#      GENE_ASXL2 GENE_ATRX  ... GENE_TET2 GENE_TP53 GENE_U2AF1 GENE_U2AF2  \
# 787       False     False  ...     False     False       True      False
# 1270      False     False  ...     False     False      False      False
# 1594      False     False  ...     False     False      False      False
# 2073      False     False  ...     False     False      False      False
# 2052      False     False  ...      True     False      False      False
#
#      GENE_WHSC1 GENE_WT1 GENE_ZBTB33 GENE_ZMYM3 GENE_ZNF318 GENE_ZRSR2
# 787       False    False       False      False       False      False
# 1270      False    False        True      False       False      False
# 1594      False    False       False      False       False       True
# 2073      False    False       False      False       False      False
# 2052      False    False       False      False       False      False
#
# [5 rows x 128 columns]

# %% [markdown]
# ### 3. Training

# %% [markdown]
# 1. Fitting Cox LASSO model

# %%
# Initialize and train the Cox Proportional Hazards model
alpha = 100
cox = CoxnetSurvivalAnalysis(l1_ratio=1, alpha_min_ratio=0.00000001)
cox.fit(X_train, y_train)

# Evaluate the model using Concordance Index IPCW
cox_cindex_train = concordance_index_ipcw(y_train, y_train, cox.predict(X_train), tau=7)[0]
cox_cindex_test = concordance_index_ipcw(y_train, y_test, cox.predict(X_test), tau=7)[0]
print(f"Cox Proportional Hazard Model Concordance Index IPCW on train: {cox_cindex_train:.5f}")
print(f"Cox Proportional Hazard Model Concordance Index IPCW on test: {cox_cindex_test:.5f}")
# Out:
# Cox Proportional Hazard Model Concordance Index IPCW on train: 0.72092
# Cox Proportional Hazard Model Concordance Index IPCW on test: 0.69898

# %%
# Print non-zero coefficients number for each feature in chunks of 25
coefs = pd.Series(np.abs(cox.coef_).sum(axis=1), index=X_train.columns)
coefs = coefs.sort_values(ascending=False)
#coefs = coefs[coefs > 0]

plt.figure(figsize=(10, 6))
chunk_size = 25
for i in range(0, len(coefs), chunk_size):
    chunk = coefs.iloc[i:i + chunk_size]
    plt.figure(figsize=(10, 6))
    chunk.plot(kind='barh')
    plt.title(f'Features {i + 1} to {i + len(chunk)}')
    plt.xlabel('Coefficient Value')
    plt.ylabel('Features')
    plt.show()

relevant_features = coefs.index.tolist()

# %% [markdown]
# ### 4. Prediction

# %% [markdown]
# 1. Calculating Nmut on prediction sample

# %%
tmp_eval = maf_eval.groupby('ID').size().reset_index(name='Nmut')

# Merge with the training dataset and replace missing values in 'Nmut' with 0
df_eval2 = df_eval.merge(tmp_eval, on='ID', how='left').fillna({'Nmut': 0})

# %% [markdown]
# 2. One hot encoding 'GENE'

# %%
# One-hot encode the 'GENE' column
one_hot_encoded_genes_eval = pd.get_dummies(maf_eval['GENE'], prefix='GENE')

# Add the one-hot encoded columns to the original DataFrame
maf_eval_one_hot = pd.concat([maf_eval[['ID']], one_hot_encoded_genes_eval], axis=1)

# Group by 'ID' and aggregate using max to ensure one entry per ID
maf_eval_one_hot_grouped = maf_eval_one_hot.groupby('ID').max().reset_index()

maf_eval_one_hot_grouped.head()
# Out:
#         ID  GENE_ARID2  GENE_ASXL1  GENE_ASXL2  GENE_ATM  GENE_BCL2  \
# 0     KYW1       False       False       False     False      False
# 1    KYW10       False       False       False     False      False
# 2   KYW100       False       False       False     False      False
# 3  KYW1000       False       False       False     False      False
# 4  KYW1001       False        True       False     False      False
#
#    GENE_BCOR  GENE_BCORL1  GENE_BLM  GENE_BRAF  ...  GENE_SUZ12  GENE_TERT  \
# 0      False        False     False      False  ...       False      False
# 1      False        False     False      False  ...       False      False
# 2      False        False     False      False  ...       False      False
# 3      False        False     False      False  ...       False      False
# 4      False        False     False      False  ...       False      False
#
#    GENE_TET2  GENE_TP53  GENE_U2AF1  GENE_U2AF2  GENE_USP9X  GENE_VEGFA  \
# 0      False      False       False       False       False       False
# 1      False      False       False       False       False       False
# 2      False      False       False       False       False       False
# 3       True      False       False       False       False       False
# 4      False      False       False       False       False       False
#
#    GENE_WT1  GENE_ZRSR2
# 0     False       False
# 1     False        True
# 2     False       False
# 3     False        True
# 4     False        True
#
# [5 rows x 84 columns]

# %% [markdown]
# 3. Align colums of X_eval with those of X_train

# %%
X_eval = df_eval2[['ID','BM_BLAST', 'HB', 'PLT', 'Nmut']].merge(maf_eval_one_hot_grouped, on='ID', how='left')
X_eval = X_eval.drop(columns=['ID'])

# Ensure X is a pandas DataFrame before accessing its columns
if not isinstance(X, pd.DataFrame):
	X = pd.DataFrame(X, columns=features+one_hot_features)

X_eval = X_eval.reindex(columns=X.columns, fill_value=False)
X_eval = X_eval.drop(columns=[col for col in X_eval.columns if col not in features+one_hot_features])
X_eval.head()
# Out:
#    BM_BLAST    HB   PLT  Nmut  GENE_ABL1  GENE_ARID1A GENE_ARID2 GENE_ASXL1  \
# 0      68.0   7.6  48.0   4.0      False        False      False      False
# 1      35.0  10.0  32.0   3.0      False        False      False      False
# 2       NaN  12.3  25.0   3.0      False        False      False       True
# 3      61.0   8.0  44.0   3.0      False        False      False      False
# 4       2.0   8.6  27.0   3.0      False        False      False       True
#
#   GENE_ASXL2  GENE_ATRX  ...  GENE_TET2  GENE_TP53 GENE_U2AF1 GENE_U2AF2  \
# 0      False      False  ...      False      False      False      False
# 1      False      False  ...      False      False      False      False
# 2      False      False  ...       True      False      False      False
# 3      False      False  ...      False      False      False      False
# 4      False      False  ...      False      False       True      False
#
#   GENE_WHSC1 GENE_WT1 GENE_ZBTB33 GENE_ZMYM3  GENE_ZNF318  GENE_ZRSR2
# 0      False    False       False      False        False       False
# 1      False    False       False      False        False       False
# 2      False    False       False      False        False       False
# 3      False     True       False      False        False       False
# 4      False    False       False      False        False       False
#
# [5 rows x 128 columns]

# %% [markdown]
# 3. Imputer with median trategy

# %%
imputer = SimpleImputer(strategy='median')
X_train[['BM_BLAST', 'HB', 'PLT', 'Nmut']] = imputer.fit_transform(X_train[['BM_BLAST', 'HB', 'PLT', 'Nmut']])
X_eval[['BM_BLAST', 'HB', 'PLT', 'Nmut']] = imputer.transform(X_eval[['BM_BLAST', 'HB', 'PLT', 'Nmut']])
X_eval = X_eval.fillna(False)
X_eval.head()
# Out:
# /tmp/ipykernel_55441/1700833979.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X_eval = X_eval.fillna(False)
#    BM_BLAST    HB   PLT  Nmut  GENE_ABL1  GENE_ARID1A  GENE_ARID2  GENE_ASXL1  \
# 0      68.0   7.6  48.0   4.0      False        False       False       False
# 1      35.0  10.0  32.0   3.0      False        False       False       False
# 2       3.5  12.3  25.0   3.0      False        False       False        True
# 3      61.0   8.0  44.0   3.0      False        False       False       False
# 4       2.0   8.6  27.0   3.0      False        False       False        True
#
#    GENE_ASXL2  GENE_ATRX  ...  GENE_TET2  GENE_TP53  GENE_U2AF1  GENE_U2AF2  \
# 0       False      False  ...      False      False       False       False
# 1       False      False  ...      False      False       False       False
# 2       False      False  ...       True      False       False       False
# 3       False      False  ...      False      False       False       False
# 4       False      False  ...      False      False        True       False
#
#    GENE_WHSC1  GENE_WT1  GENE_ZBTB33  GENE_ZMYM3  GENE_ZNF318  GENE_ZRSR2
# 0       False     False        False       False        False       False
# 1       False     False        False       False        False       False
# 2       False     False        False       False        False       False
# 3       False      True        False       False        False       False
# 4       False     False        False       False        False       False
#
# [5 rows x 128 columns]

# %%
prediction_on_test_set = cox.predict(X_eval)
prediction_on_test_set
# Out:
# array([ 2.81710498,  0.73987513, -0.60061942, ...,  0.68161171,
#        -0.28497473,  1.13602163])

# %%
submission = pd.Series(prediction_on_test_set, index=df_eval['ID'], name='risk_score')

# %%
submission.to_csv('./submission/cox_ridge_submission.csv')

# %%
submission.head()
# Out:
# ID
# KYW1    2.817105
# KYW2    0.739875
# KYW3   -0.600619
# KYW4    2.136741
# KYW5    0.214674
# Name: risk_score, dtype: float64
